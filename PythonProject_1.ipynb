# %%
import pandas as pd

# %%
df = pd.read_csv(r"https://github.com/stevewatkins17/PythonForDataAnalysis/raw/Jan2020/IpythonNotebooks/Data/demo_AmexTransactions.csv")

# %%
df
# Out:
#    01/01/2018  Mon  Unnamed: 1                    THORNTONS - PROSPECT, KY  \
# 0  01/02/2018  Tue         NaN   GOOGLE *GOOGLE STORAGE - 855-836-3987, CA
# 1  01/02/2018  Tue         NaN                    THORNTONS - PROSPECT, KY
# 2  01/03/2018  Wed         NaN    AMAZON MKTPLACE PMTS - AMZN.COM/BILL, WA
# 3  01/03/2018  Wed         NaN    Amazon Web Services - AWS.Amazon.com, WA
# 4  01/11/2018  Thu         NaN  TRADER JOE'S #628 QPS 628 - LOUISVILLE, KY
# 5  10/20/2018  Sat         NaN                 SEATGEEK_TICKETS - NEW YORK
# 6  10/22/2018  Mon         NaN                 SEATGEEK_TICKETS - NEW YORK
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5          Transportation  Unnamed: 7  \
# 0         NaN         NaN         NaN       Business Services         NaN
# 1         NaN         NaN         NaN          Transportation         NaN
# 2         NaN         NaN         NaN  Merchandise & Supplies         NaN
# ...
